# %%
import numpy as np
import cv2 
import matplotlib.pyplot as plt

# %%
def displayImage(image):
    plt.imshow(image, cmap='gray')
    plt.show()

# %%
binary_image= np.zeros((300,300), dtype=np.uint8)
binary_image[75:225,75:225]=255
displayImage(binary_image)

# %%
concat1 = cv2.imread('C:\\Users\\Hp\\Downloads\\concat1.jpg',0)
#displayImage(concat1)
cv2.imshow("img1",concat1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
concat2 = cv2.imread('C:\\Users\\Hp\\Downloads\\concat2.jpg',0)
#displayImage(concat2)
cv2.imshow("img2",concat2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
concat3 = cv2.imread('C:\\Users\\Hp\Downloads\\concat3.jpg',0)
#displayImage(concat3)
cv2.imshow("img3",concat3)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image1=cv2.hconcat([concat1,concat2])
displayImage(image1)

# %%
image2=cv2.hconcat([image1,concat3])
displayImage(image2)

# %%
image = cv2.imread('C:\\Users\\Hp\\Downloads\\threshold.jpg',0)
print(image.shape)
# Out:
# (1067, 1600)

# %%
img_threshold = np.array(image)

for i in range(1067):
  for j in range(1600):
     if img_threshold[i,j]<70:
      img_threshold[i,j]=0
    
displayImage(img_threshold)

# %%
img1 = cv2.imread('C:\\Users\\Hp\\Downloads\\feature1.jpeg',cv2.IMREAD_GRAYSCALE) 
img2 = cv2.imread('C:\\Users\\Hp\\Downloads\\feature2.jpeg',cv2.IMREAD_GRAYSCALE) 

orb = cv2.ORB_create()

kp1, des1 = orb.detectAndCompute(img1,None)
kp2, des2 = orb.detectAndCompute(img2,None)



bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
matches = bf.match(des1,des2)
matches = sorted(matches, key = lambda x:x.distance)

RESULT = cv2.drawMatches(img1,kp1,img2,kp2,matches,None)

displayImage(RESULT)

# %%
point1 = None
point2 = None
segment = None

def colorFunction(event,x,y,flag,param):
    global point1, point2, segment
    if event == cv2.EVENT_LBUTTONDOWN:
        if point1 is None:
            point1 = (x,y)
            print(f"Point 1: {point1}")
            
        elif point2 is None:
            point2 = (x,y)
            print(f"Point 2: {point2}")
             
            
            minY= min(point1[1],point2[1])
            maxY= max(point1[1],point2[1])
            
           
            segment =cv2.rectangle(towers, minY, maxY, (255,0,0), -1) 
            


towers = cv2.imread('C:\\Users\\Hp\\Downloads\\skyline.jpg', 0)
cv2.namedWindow('Tower')
cv2.setMouseCallback('Tower',colorFunction)

while(1):
    cv2.imshow('Tower',towers)
    if segment is not None:
        cv2.imshow('Segment', segment)
    key = cv2.waitKey(1)
    if key == 27:
        break
cv2.destroyAllWindows()
# Out:
# Point 1: (830, 208)
# Point 2: (823, 583)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[25], line 21, in colorFunction(event, x, y, flag, param)
#      17 minY= min(point1[1],point2[1])
#      18 maxY= max(point1[1],point2[1])
# ---> 21 segment =cv2.rectangle(towers, minY, maxY, (255,0,0), 2)
#
# error: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'rectangle'
# > Overload resolution failed:
# >  - Can't parse 'pt1'. Input argument doesn't provide sequence protocol
# >  - Can't parse 'pt1'. Input argument doesn't provide sequence protocol
# >  - Can't parse 'rec'. Input argument doesn't provide sequence protocol
# >  - Can't parse 'rec'. Input argument doesn't provide sequence protocol
